# %%
import json
import requests
import cv2 as cv
from PIL import Image
import os
import sys
import glob
import pandas as pd
import tensorflow as tf

# %%
#reads the json file

filename = 'data_images.json'
jsonData =[]
count =0
with open(filename, "r") as jsonfile:
    for line in jsonfile:
        count +=1
        jsonData.append(json.loads(str(line.strip())))
        
print("number of rows:",count)
# Out:
# number of rows: 409

# %%
#Download images

path = './images/image_'
count = 1
for image_data in jsonData:
    url = image_data['content']
    r = requests.get(url)
    ext = url.split('.')[-1]
    with open(path+str(count)+'.'+ext,'wb') as f: 
        f.write(r.content)
    count +=1

# %%
jsonData[0]['annotation'][0]
# Out:
# {'label': ['Face'],
#  'notes': '',
#  'points': [{'x': 0.08615384615384615, 'y': 0.3063063063063063},
#   {'x': 0.1723076923076923, 'y': 0.45345345345345345}],
#  'imageWidth': 650,
#  'imageHeight': 333}

# %%
from_range = 1
to_range = 409
filename = 'trainval.txt'
count = 1
with open(filename, 'w') as file:
    for count in range(1,409):
        file.write("image_"+str(count)+"\n")
        count = count+1

# %%
#create the dataframe in required format

#For trainSet use from_range= 1 to_range=300 filename = train_label.csv
#For testset use from_range = 301 to_range=409 filename = test_label.csv

from_range = 1
to_range = 300
filename = 'train_label.csv'

column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
output_df_list = []
path = 'image_'
count = 1
for i in range(from_range,to_range):
    #print(i)
    ext = jsonData[i-1]['content'].split(".")[-1]
    for t in jsonData[i-1]['annotation']:
        label = t['label']
        points = t['points']
        imageWidth = int(t['imageWidth'])
        imageHeight = int(t['imageHeight'])
        x1 = int(float(points[0]['x'])*imageWidth)
        y1 = int(float(points[0]['y'])*imageHeight)
        x2 = int(float(points[1]['x'])*imageWidth)
        y2= int(float(points[1]['y'])*imageHeight)
        xmin = min(x1,x2)
        ymin = min(y1,y2)
        xmax = max(x1,x2)
        ymax = max(y1,y2)
        width = xmax-xmin
        height = ymax-ymin
        #print(width,height)
        if(width >0 and height > 0):
            image_list = [path+str(i)+"."+ext, width,height,'face',xmin,ymin,xmax,ymax]
            output_df_list.append(image_list)
            
xml_df = pd.DataFrame(output_df_list, columns=column_name)
xml_df.to_csv(filename, index=None)

# %%
#create the dataframe in required format

#For trainSet use from_range= 1 to_range=300 filename = train_label.csv
#For testset use from_range = 301 to_range=409 filename = test_label.csv

from_range = 301
to_range = 409
filename = 'test_label.csv'

column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
output_df_list = []
path = 'image_'
count = 1
for i in range(from_range,to_range):
    #print(i)
    ext = jsonData[i-1]['content'].split(".")[-1]
    for t in jsonData[i-1]['annotation']:
        label = t['label']
        points = t['points']
        imageWidth = int(t['imageWidth'])
        imageHeight = int(t['imageHeight'])
        x1 = int(float(points[0]['x'])*imageWidth)
        y1 = int(float(points[0]['y'])*imageHeight)
        x2 = int(float(points[1]['x'])*imageWidth)
        y2= int(float(points[1]['y'])*imageHeight)
        xmin = min(x1,x2)
        ymin = min(y1,y2)
        xmax = max(x1,x2)
        ymax = max(y1,y2)
        width = xmax-xmin
        height = ymax-ymin
        #print(width,height)
        if(width >0 and height > 0):
            image_list = [path+str(i)+"."+ext, width,height,'face',xmin,ymin,xmax,ymax]
            output_df_list.append(image_list)
            
xml_df = pd.DataFrame(output_df_list, columns=column_name)
xml_df.to_csv(filename, index=None)

# %%
#Dummy

#xml_df = pd.DataFrame(output_df_list, columns=column_name)

# %%
#dummy
#xml_df.to_csv('image_labels.csv', index=None)
#print('Successfully converted xml to csv.')
# Out:
# Successfully converted xml to csv.

# %%
xml_df
# Out:
#            filename  width  height class  xmin  ymin  xmax  ymax
# 0    image_301.jpeg     80     111  face   127    14   207   125
# 1    image_302.jpeg    901     907  face   459   231  1360  1138
# 2    image_303.jpeg    123     156  face     3    46   126   202
# 3    image_303.jpeg     99     132  face   139    46   238   178
# 4    image_303.jpeg    130     153  face   270    29   400   182
# 5    image_303.jpeg    157     165  face   379     2   536   167
# 6    image_304.jpeg    180     233  face    23    18   203   251
# 7    image_304.jpeg     81     113  face   267    17   348   130
# 8    image_304.jpeg    154     259  face   439    15   593   274
# 9    image_305.jpeg    179     181  face   867    62  1046   243
# 10   image_305.jpeg    185     150  face  1356   147  1541   297
# 11   image_305.jpeg    143     144  face   416   322   559   466
# 12   image_306.jpeg     87      91  face   348    19   435   110
# 13   image_306.jpeg    196     160  face   154   275   350   435
# 14   image_306.jpeg     99     105  face   342   551   441   656
# 15   image_306.jpeg    255     185  face   180   832   435  1017
# 16   image_307.jpeg     81     104  face   411   352   492   456
# 17   image_308.jpeg    145     137  face   366   170   511   307
# 18   image_308.jpeg    108     121  face   955    73  1063   194
# 19   image_308.jpeg    132     171  face  1577   138  1709   309
# 20   image_309.jpeg     82      99  face    91    12   173   111
# 21   image_310.jpeg    203     261  face   172   169   375   430
# 22   image_310.jpeg    196     239  face   297    64   493   303
# 23   image_310.jpeg    262     425  face   509    91   771   516
# 24   image_310.jpeg    217     290  face   800    73  1017   363
# 25   image_310.jpeg    184     388  face  1014   209  1198   597
# 26   image_311.jpeg    221     269  face   140   192   361   461
# 27   image_311.jpeg    202     180  face   762   485   964   665
# 28   image_311.jpeg    214     260  face   650    78   864   338
# 29   image_311.jpeg    223     243  face  1291   123  1514   366
# ..              ...    ...     ...   ...   ...   ...   ...   ...
# 290  image_396.jpeg     72      82  face   370    88   442   170
# 291  image_396.jpeg     57      60  face   502    96   559   156
# 292  image_396.jpeg     71      71  face   569    83   640   154
# 293  image_396.jpeg     63      75  face   277    37   340   112
# 294   image_397.png     65      60  face   325    49   390   109
# 295   image_397.png     73      68  face   601    50   674   118
# 296  image_398.jpeg     97      99  face   196   163   293   262
# 297  image_398.jpeg     65      73  face   434   210   499   283
# 298  image_398.jpeg     87     101  face   526   217   613   318
# 299  image_398.jpeg     25      22  face   323   495   348   517
# 300  image_398.jpeg     26      22  face   269   510   295   532
# 301  image_399.jpeg     95     104  face   350    46   445   150
# 302  image_400.jpeg    193     198  face   430    63   623   261
# 303  image_401.jpeg    326     326  face   488   323   814   649
# 304  image_401.jpeg    266     283  face   158   527   424   810
# 305  image_401.jpeg    271     323  face   721   836   992  1159
# 306  image_402.jpeg     48      53  face   364    99   412   152
# 307  image_403.jpeg    108     120  face   323   129   431   249
# 308  image_403.jpeg     94     137  face   522    50   616   187
# 309  image_403.jpeg     88      63  face   614   220   702   283
# 310  image_403.jpeg     99     113  face   753   207   852   320
# 311  image_403.jpeg     76      98  face   898   123   974   221
# 312  image_403.jpeg    103     107  face  1067    48  1170   155
# 313  image_403.jpeg    105     123  face  1234   117  1339   240
# 314   image_404.png    303     336  face   837   273  1140   609
# 315  image_405.jpeg    546     598  face   220    13   766   611
# 316  image_406.jpeg    382     422  face   777    66  1159   488
# 317  image_407.jpeg    215     249  face   424     4   639   253
# 318  image_408.jpeg    104     136  face   189   182   293   318
# 319  image_408.jpeg    152     146  face   543   180   695   326
#
# [320 rows x 8 columns]
